# %%
#basic
import pandas as pd
import numpy as np

#plot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(16,8)})
sns.set(font_scale=1.3)
plt.style.use("fivethirtyeight")
# %matplotlib inline
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# For reading stock data 
from pandas_datareader.data import DataReader

# For time stamps
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

#modeling
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt, ExponentialSmoothing
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

np.random.seed(123)

# %% [markdown]
# ### Univariate time series
# * ARIMA: combines both Autoregression (AR) and Moving Average (MA) models as well as a differencing pre-processing step of the sequence to make the sequence stationary, called integration (I). AR(p), I(d), and MA(q) models as parameters
# * ARIMA(data, order=(1, 1, 1))
#
# * SARIMA: combines the ARIMA model with the ability to perform the same autoregression, differencing, and moving average modeling at the seasonal level. SARIMA(p, d, q)(P, D, Q)m where  AR(P), I(D), MA(Q) and m parameters at the seasonal level, “m” is the number of time steps in each season (the seasonal period)
# * SARIMAX(data, order=(1, 1, 1), seasonal_order=(0, 0, 0, 0))
#
# * SARIMAX: Exogenous variables are also called covariates and can be thought of as parallel input sequences that have observations at the same time steps as the original series.
# * SARIMAX(data1, exog=data2, order=(1, 1, 1), seasonal_order=(0, 0, 0, 0))

# %%
df = DataReader('AAL', data_source='yahoo', start='2012-01-01', end=datetime.now())

# %%
data = df.filter(['Close'])

# %%
dataset = data.values

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

# %%
training_data_len = int(np.ceil( len(dataset) * .9 ))
train_data = scaled_data[0:int(training_data_len), :]

# %%
train_data.shape
# Out:
# (2192, 1)

# %% [markdown]
# ## ARISM

# %%
plt.figure(figsize=(16,8))
plt.plot(data['Close'], label='Close.',color='r')
plt.xlabel('Date',size=20)
plt.ylabel('Stock Price',size=20)
plt.title('Stock Price Over the Years',size=25);

# %%
def adfuller_test(stocks):
    result=adfuller(stocks)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

# %%
adfuller_test(data)
# Out:
# ADF Test Statistic : -2.025045442000766
# p-value : 0.2757006480664766
# #Lags Used : 1
# Number of Observations : 2433

# %%
autocorrelation_plot(data['Close'])
plt.show()

# %%
data['Close First diff'] = data['Close'] - data['Close'].shift(1)
data['Close Seasonal diff']=data['Close']- data['Close'].shift(12)
data.head()
# Out:
#             Close  Close First diff  Close Seasonal diff
# Date
# 2012-01-03   5.12               NaN                  NaN
# 2012-01-04   5.03             -0.09                  NaN
# 2012-01-05   5.47              0.44                  NaN
# 2012-01-06   5.60              0.13                  NaN
# 2012-01-09   5.72              0.12                  NaN

# %%
adfuller_test(data['Close Seasonal diff'].dropna())

#rejecting the null hypothesis. So data is stationary.
# Out:
# ADF Test Statistic : -7.818746154519208
# p-value : 6.7588076277770386e-12
# #Lags Used : 24
# Number of Observations : 2398

# %%
plt.figure(figsize=(16,8))
plt.plot(data['Close Seasonal diff'], label='Close Seasonal Diff.',color='r')
plt.xlabel('Date',size=20)
plt.ylabel('Stock Price',size=20)
plt.title('Stock Price Over the Years',size=25);

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(data['Close Seasonal diff'].dropna(),lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(data['Close Seasonal diff'].dropna(),lags=40,ax=ax2)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(data['Close'])
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
train_data, test_data = df_log[0:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
len(test_data)
# Out:
# 244

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=9, max_q=9, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-8936.575, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-8957.477, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-8957.982, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-8938.120, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-8955.991, Time=0.26 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-8955.997, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-8954.024, Time=0.61 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-8959.603, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-8957.611, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-8957.536, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-8959.104, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-8958.669, Time=0.35 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.255 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2191
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                4481.802
# Date:                Mon, 06 Sep 2021   AIC                          -8959.603
# Time:                        19:14:20   BIC                          -8948.220
# Sample:                             0   HQIC                         -8955.443
#                                - 2191
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1036      0.012      8.356      0.000       0.079       0.128
# sigma2         0.0010   9.76e-06    100.111      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             25991.14
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.02   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# 1. The top left plot shows the residuals over time. We do not want to see any obvious seasonality here and the messier it is, the better we can say we found the trend and seasonality in our data and removed the noise.
#
# 2. In the top-right plot, we want to see that the red KDE line follows closely with the N(0,1) line to indicate that the residuals are normally distributed. This line is the standard notation for a normal distribution with a mean of 0 and a standard deviation of 1.
#
# 3. In the bottom left qq-plot, you see the ordered distribution of residuals (blue dots) following the linear trend (red line) of the samples taken from a standard normal distribution with N(0, 1).
#
# 4. The autocorrelation visual (called a “correlogram”) on the bottom right shows that the time series residuals have a low correlation with the lagged versions of itself (that is, the majority of dots fall into the blue shaded area).

# %%
#The best ARIMA model with p,d,q values is 0,1,1 and Seasonal P,D,Q with 0,0,0

model = ARIMA(train_data, order=(0,1,1))  
fitted = model.fit(disp=-1)  
print(fitted.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                 2190
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                4481.991
# Method:                       css-mle   S.D. of innovations              0.031
# Date:                Mon, 06 Sep 2021   AIC                          -8957.982
# Time:                        19:15:41   BIC                          -8940.907
# Sample:                             1   HQIC                         -8951.742
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0005      0.001      0.616      0.538      -0.001       0.002
# ma.L1.D.Close     0.1040      0.021      4.889      0.000       0.062       0.146
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -9.6179           +0.0000j            9.6179            0.5000
# -----------------------------------------------------------------------------

# %%
fc, se, conf = fitted.forecast(244, alpha=0.05)  #95% conf

# %%
# Make as pandas series

fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)

# Plot
with plt.style.context('images/presentation.mplstyle'):
    plt.figure(figsize=(10,5), dpi=100)
    plt.plot(train_data, label='training data')
    plt.plot(test_data, color = 'blue', label='Actual Stock Price')
    plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
    plt.fill_between(lower_series.index, lower_series, upper_series, 
                     color='k', alpha=.10)
    plt.title('Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.legend(loc='upper left', fontsize=8)
    plt.show()
    plt.savefig('images/ARIMA.png')

# %%
# report performance
mse = mean_squared_error(test_data, fc)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, fc)
print('MAE: '+str(mae))
rmse = sqrt(mean_squared_error(test_data, fc))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
# Out:
# MSE: 0.08977969408274275
# MAE: 0.2641704237889892
# RMSE: 0.29963259849813195
# MAPE: 0.0883222508397932

# %%
from matplotlib import pyplot

size = int(len(dataset) * 0.9)
train, test = dataset[0:size], dataset[size:len(dataset)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=13.842235, expected=13.630000
# predicted=13.627711, expected=13.190000
# predicted=13.146377, expected=12.210000
# predicted=12.146651, expected=12.340000
# predicted=12.352078, expected=11.930000
# predicted=11.929090, expected=11.770000
# predicted=11.762564, expected=12.290000
# predicted=12.344455, expected=12.760000
# predicted=12.801545, expected=12.250000
# predicted=12.212959, expected=12.290000
# predicted=12.283478, expected=12.580000
# predicted=12.608828, expected=13.000000
# predicted=13.029834, expected=13.120000
# predicted=13.131604, expected=12.530000
# predicted=12.483223, expected=13.070000
# predicted=13.101887, expected=13.160000
# predicted=13.181179, expected=13.200000
# predicted=13.195186, expected=12.920000
# predicted=12.906275, expected=12.220000
# predicted=12.168498, expected=12.360000
# predicted=12.374824, expected=12.230000
# predicted=12.240254, expected=12.460000
# predicted=12.478941, expected=12.560000
# predicted=12.579121, expected=12.800000
# predicted=12.814371, expected=12.750000
# predicted=12.749350, expected=13.150000
# predicted=13.173333, expected=12.600000
# predicted=12.567359, expected=11.800000
# predicted=11.734990, expected=11.230000
# predicted=11.201258, expected=10.950000
# predicted=10.945934, expected=11.160000
# predicted=11.194561, expected=11.280000
# predicted=11.305913, expected=11.190000
# predicted=11.187611, expected=11.250000
# predicted=11.255479, expected=11.010000
# predicted=10.996294, expected=11.600000
# predicted=11.640135, expected=11.460000
# predicted=11.461808, expected=13.200000
# predicted=13.308707, expected=12.380000
# predicted=12.341638, expected=12.040000
# predicted=11.971709, expected=11.740000
# predicted=11.736892, expected=12.240000
# predicted=12.270069, expected=12.790000
# predicted=12.847086, expected=12.700000
# predicted=12.691504, expected=12.740000
# predicted=12.734025, expected=12.790000
# predicted=12.794174, expected=12.530000
# predicted=12.510867, expected=13.560000
# predicted=13.631167, expected=14.820000
# predicted=14.921037, expected=14.940000
# predicted=14.935012, expected=14.980000
# predicted=14.958243, expected=14.130000
# predicted=14.062603, expected=14.270000
# predicted=14.269023, expected=14.860000
# predicted=14.924421, expected=16.090000
# predicted=16.180309, expected=16.400000
# predicted=16.423008, expected=17.209999
# predicted=17.240718, expected=17.629999
# predicted=17.654798, expected=17.160000
# predicted=17.106101, expected=17.990000
# predicted=18.036119, expected=17.049999
# predicted=17.000537, expected=16.700001
# predicted=16.654599, expected=17.010000
# predicted=17.056751, expected=16.860001
# predicted=16.862327, expected=16.799999
# predicted=16.800072, expected=16.510000
# predicted=16.499417, expected=16.100000
# predicted=16.074942, expected=15.480000
# predicted=15.447446, expected=15.890000
# predicted=15.930007, expected=15.660000
# predicted=15.668690, expected=16.059999
# predicted=16.085637, expected=15.860000
# predicted=15.861341, expected=16.150000
# predicted=16.161837, expected=15.770000
# predicted=15.755445, expected=15.130000
# predicted=15.079528, expected=15.430000
# predicted=15.460336, expected=15.520000
# predicted=15.546658, expected=15.380000
# predicted=15.372790, expected=15.130000
# predicted=15.117468, expected=15.000000
# predicted=14.994970, expected=15.380000
# predicted=15.415209, expected=15.530000
# predicted=15.551480, expected=16.440001
# predicted=16.500732, expected=15.760000
# predicted=15.719777, expected=15.970000
# predicted=15.960163, expected=16.170000
# predicted=16.201757, expected=15.830000
# predicted=15.804338, expected=15.820000
# predicted=15.820670, expected=15.430000
# predicted=15.413952, expected=15.530000
# predicted=15.538987, expected=16.559999
# predicted=16.646292, expected=18.100000
# predicted=18.216106, expected=17.170000
# predicted=17.097465, expected=16.840000
# predicted=16.776842, expected=16.590000
# predicted=16.587142, expected=17.600000
# predicted=17.674325, expected=17.400000
# predicted=17.408996, expected=17.190001
# predicted=17.157240, expected=17.770000
# predicted=17.817477, expected=17.440001
# predicted=17.425445, expected=17.410000
# predicted=17.399133, expected=16.990000
# predicted=16.974380, expected=17.270000
# predicted=17.290085, expected=17.820000
# predicted=17.875934, expected=17.990000
# predicted=18.003726, expected=17.709999
# predicted=17.685243, expected=18.680000
# predicted=18.742497, expected=20.440001
# predicted=20.574102, expected=20.660000
# predicted=20.665076, expected=21.820000
# predicted=21.865673, expected=20.860001
# predicted=20.793025, expected=20.940001
# predicted=20.908338, expected=21.180000
# predicted=21.223023, expected=21.440001
# predicted=21.460248, expected=22.170000
# predicted=22.226001, expected=21.240000
# predicted=21.180718, expected=20.450001
# predicted=20.378285, expected=21.469999
# predicted=21.561487, expected=21.600000
# predicted=21.639261, expected=21.750000
# predicted=21.748209, expected=22.150000
# predicted=22.181438, expected=23.370001
# predicted=23.453582, expected=25.170000
# predicted=25.298182, expected=24.469999
# predicted=24.407579, expected=25.160000
# predicted=25.165083, expected=24.700001
# predicted=24.689402, expected=24.969999
# predicted=24.972806, expected=23.830000
# predicted=23.776372, expected=22.270000
# predicted=22.155930, expected=21.809999
# predicted=21.805120, expected=22.770000
# predicted=22.880496, expected=22.930000
# predicted=22.972220, expected=22.910000
# predicted=22.900029, expected=24.120001
# predicted=24.207033, expected=23.900000
# predicted=23.893889, expected=23.860001
# predicted=23.833695, expected=24.230000
# predicted=24.265462, expected=24.059999
# predicted=24.053196, expected=23.930000
# predicted=23.920469, expected=23.650000
# predicted=23.641302, expected=23.540001
# predicted=23.540268, expected=22.910000
# predicted=22.881753, expected=22.559999
# predicted=22.544059, expected=22.370001
# predicted=22.379115, expected=22.129999
# predicted=22.129953, expected=22.030001
# predicted=22.037524, expected=21.549999
# predicted=21.531279, expected=20.370001
# predicted=20.296337, expected=21.010000
# predicted=21.066845, expected=20.070000
# predicted=20.045205, expected=21.110001
# predicted=21.170034, expected=22.040001
# predicted=22.142245, expected=21.760000
# predicted=21.728721, expected=21.700001
# predicted=21.680478, expected=21.299999
# predicted=21.277892, expected=21.719999
# predicted=21.751156, expected=21.950001
# predicted=21.985610, expected=21.420000
# predicted=21.383835, expected=21.570000
# predicted=21.578693, expected=21.490000
# predicted=21.502133, expected=22.000000
# predicted=22.038010, expected=22.000000
# predicted=22.013209, expected=21.570000
# predicted=21.535361, expected=20.760000
# predicted=20.707999, expected=21.209999
# predicted=21.250811, expected=22.400000
# predicted=22.510591, expected=23.350000
# predicted=23.421165, expected=23.559999
# predicted=23.558615, expected=22.969999
# predicted=22.908495, expected=22.600000
# predicted=22.566234, expected=22.570000
# predicted=22.584260, expected=22.990000
# predicted=23.036746, expected=23.209999
# predicted=23.238270, expected=23.900000
# predicted=23.946539, expected=24.430000
# predicted=24.470431, expected=24.240000
# predicted=24.217428, expected=24.670000
# predicted=24.689681, expected=25.820000
# predicted=25.910261, expected=24.930000
# predicted=24.870712, expected=24.299999
# predicted=24.231650, expected=24.250000
# predicted=24.267986, expected=24.219999
# predicted=24.240002, expected=23.850000
# predicted=23.839149, expected=23.459999
# predicted=23.442499, expected=23.530001
# predicted=23.550062, expected=22.990000
# predicted=22.971375, expected=22.790001
# predicted=22.782179, expected=22.830000
# predicted=22.853535, expected=22.230000
# predicted=22.202294, expected=22.290001
# predicted=22.300230, expected=22.450001
# predicted=22.483340, expected=22.110001
# predicted=22.094650, expected=22.200001
# predicted=22.209805, expected=22.350000
# predicted=22.374963, expected=22.219999
# predicted=22.216986, expected=21.389999
# predicted=21.336502, expected=21.080000
# predicted=21.064057, expected=21.209999
# predicted=21.244013, expected=21.510000
# predicted=21.548433, expected=21.480000
# predicted=21.486670, expected=21.010000
# predicted=20.977355, expected=20.309999
# predicted=20.265352, expected=20.350000
# predicted=20.366721, expected=20.889999
# predicted=20.952446, expected=20.840000
# predicted=20.847583, expected=20.020000
# predicted=19.958079, expected=20.620001
# predicted=20.664210, expected=20.459999
# predicted=20.475415, expected=19.790001
# predicted=19.737603, expected=18.969999
# predicted=18.922255, expected=20.559999
# predicted=20.686327, expected=21.400000
# predicted=21.489861, expected=21.160000
# predicted=21.116755, expected=21.200001
# predicted=21.188958, expected=22.080000
# predicted=22.144689, expected=21.459999
# predicted=21.420296, expected=21.629999
# predicted=21.627353, expected=21.170000
# predicted=21.158991, expected=20.379999
# predicted=20.323514, expected=20.059999
# predicted=20.056536, expected=19.950001
# predicted=19.966316, expected=19.450001
# predicted=19.432328, expected=20.910000
# predicted=21.022682, expected=21.020000
# predicted=21.050709, expected=20.559999
# predicted=20.502214, expected=20.940001
# predicted=20.968410, expected=21.230000
# predicted=21.258570, expected=20.430000
# predicted=20.373608, expected=19.840000
# predicted=19.800358, expected=19.760000
# predicted=19.775037, expected=19.340000
# predicted=19.329984, expected=19.139999
# predicted=19.139723, expected=18.730000
# predicted=18.720679, expected=18.500000
# predicted=18.494777, expected=19.110001
# predicted=19.169379, expected=19.830000
# predicted=19.893329, expected=20.150000
# predicted=20.168045, expected=19.900000
# predicted=19.872771, expected=20.219999
# predicted=20.234833, expected=19.510000
# predicted=19.467596, expected=19.940001
# predicted=19.965096, expected=19.639999
# predicted=19.643546, expected=19.760000
# predicted=19.762672, expected=19.370001
# Test RMSE: 0.581

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

train_st = df.ix[:-24, "station"]
test_st = df.ix[-24:, "station"]
sarima_model = SARIMAX(train_st, order=(0, 1, 2), seasonal_order=(0, 1, 2, 12), enforce_invertibility=False, enforce_stationarity=False)
sarima_fit = sarima_model.fit()

sarima_pred = sarima_fit.get_prediction("1974-01", "1975-12")
predicted_means = p.predicted_mean + df.data.iloc[-36:-1].rolling(12).mean().dropna().values
predicted_intervals = p.conf_int(alpha=0.05)
lower_bounds = predicted_intervals['lower station'] + df.data.iloc[-36:-1].rolling(12).mean().dropna().values
upper_bounds = predicted_intervals['upper station'] + df.data.iloc[-36:-1].rolling(12).mean().dropna().values

sarima_rmse = np.sqrt(np.mean(np.square(test_st.values - p.predicted_mean.values)))

fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(df.data.index[100:-24], df.data.values[100:-24]);
ax.plot(test_st.index, test_st.values + df.data.iloc[-36:-1].rolling(12).mean().dropna().values, label='truth');
ax.plot(test_st.index, predicted_means, color='#ff7823', linestyle='--', label="prediction (RMSE={:0.2f})".format(sarima_rmse));
ax.fill_between(test_st.index, lower_bounds, upper_bounds, color='#ff7823', alpha=0.3, label="confidence interval (95%)");
ax.legend();
ax.set_title("SARIMA");

# %%
import itertools

def sarima_grid_search(y,seasonal_period):
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2],seasonal_period) for x in list(itertools.product(p, d, q))]
    
    mini = float('+inf')
    
    
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                mod = sm.tsa.statespace.SARIMAX(y,
                                                order=param,
                                                seasonal_order=param_seasonal,
                                                enforce_stationarity=False,
                                                enforce_invertibility=False)

                results = mod.fit()
                
                if results.aic < mini:
                    mini = results.aic
                    param_mini = param
                    param_seasonal_mini = param_seasonal

#                 print('SARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            except:
                continue
    print('The set of parameters with the minimum AIC is: SARIMA{}x{} - AIC:{}'.format(param_mini, param_seasonal_mini, mini))

# %%
sarima_grid_search(y,52)

# %%
# Call this function after pick the right(p,d,q) for SARIMA based on AIC               
def sarima_eva(y,order,seasonal_order,seasonal_period,pred_date,y_to_test):
    # fit the model 
    mod = sm.tsa.statespace.SARIMAX(y,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)

    results = mod.fit()
    print(results.summary().tables[1])
    
    results.plot_diagnostics(figsize=(16, 8))
    plt.show()
    
    # The dynamic=False argument ensures that we produce one-step ahead forecasts, 
    # meaning that forecasts at each point are generated using the full history up to that point.
    pred = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=False)
    pred_ci = pred.conf_int()
    y_forecasted = pred.predicted_mean
    mse = ((y_forecasted - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = False {}'.format(seasonal_period,round(np.sqrt(mse), 2)))

    ax = y.plot(label='observed')
    y_forecasted.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('Date')
    ax.set_ylabel('Sessions')
    plt.legend()
    plt.show()

    # A better representation of our true predictive power can be obtained using dynamic forecasts. 
    # In this case, we only use information from the time series up to a certain point, 
    # and after that, forecasts are generated using values from previous forecasted time points.
    pred_dynamic = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=True, full_results=True)
    pred_dynamic_ci = pred_dynamic.conf_int()
    y_forecasted_dynamic = pred_dynamic.predicted_mean
    mse_dynamic = ((y_forecasted_dynamic - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = True {}'.format(seasonal_period,round(np.sqrt(mse_dynamic), 2)))

    ax = y.plot(label='observed')
    y_forecasted_dynamic.plot(label='Dynamic Forecast', ax=ax,figsize=(14, 7))
    ax.fill_between(pred_dynamic_ci.index,
                    pred_dynamic_ci.iloc[:, 0],
                    pred_dynamic_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('Date')
    ax.set_ylabel('Sessions')

    plt.legend()
    plt.show()
    
    return (results)

# %%
model = sarima_eva(y,(1, 1, 1),(1, 1, 0, 52),52,'2019-06-02',y_to_val)

# %%
def forecast(model,predict_steps,y):
    
    pred_uc = model.get_forecast(steps=predict_steps)

    #SARIMAXResults.conf_int, can change alpha,the default alpha = .05 returns a 95% confidence interval.
    pred_ci = pred_uc.conf_int()

    ax = y.plot(label='observed', figsize=(14, 7))
#     print(pred_uc.predicted_mean)
    pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.25)
    ax.set_xlabel('Date')
    ax.set_ylabel(y.name)

    plt.legend()
    plt.show()
    
    # Produce the forcasted tables 
    pm = pred_uc.predicted_mean.reset_index()
    pm.columns = ['Date','Predicted_Mean']
    pci = pred_ci.reset_index()
    pci.columns = ['Date','Lower Bound','Upper Bound']
    final_table = pm.join(pci.set_index('Date'), on='Date')
    
    return (final_table)

# %%
final_table = forecast(model,52,y)
final_table.head()
