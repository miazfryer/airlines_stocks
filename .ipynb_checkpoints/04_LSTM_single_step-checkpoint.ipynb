# %%
#basic
import pandas as pd
import numpy as np

#plot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline


# For reading stock data 
from pandas_datareader.data import DataReader

# For time stamps
from datetime import datetime

#for evaluation
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error, mean_absolute_error

#for modeling
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, RepeatVector, TimeDistributed, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import warnings
warnings.filterwarnings('ignore')

from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima

np.random.seed(123)

# %% [markdown]
# # Load Data

# %%
df = DataReader('LUV', data_source='yahoo', start='2012-01-01', end=datetime.now())
df
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2012-01-03   8.760000   8.410000   8.720000   8.410000  8808600.0   7.824934
# 2012-01-04   8.610000   8.220000   8.410000   8.600000  7582700.0   8.001719
# 2012-01-05   8.640000   8.390000   8.570000   8.620000  4892200.0   8.020328
# 2012-01-06   8.700000   8.520000   8.630000   8.520000  3046800.0   7.927283
# 2012-01-09   8.680000   8.520000   8.520000   8.590000  2906900.0   7.992411
# ...               ...        ...        ...        ...        ...        ...
# 2021-08-31  50.029999  48.889999  49.020000  49.779999  6431200.0  49.779999
# 2021-09-01  50.110001  49.419998  50.000000  49.549999  4509200.0  49.549999
# 2021-09-02  50.160000  49.040001  49.560001  49.599998  4966700.0  49.599998
# 2021-09-03  49.820000  48.669998  49.340000  48.860001  5201800.0  48.860001
# 2021-09-07  48.740002  48.080002  48.360001  48.419998  1072400.0  48.419998
#
# [2436 rows x 6 columns]

# %% [markdown]
# # Modeling

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column
#data= AAPL['Close'].values.reshape(-1, 1)
data = df.filter(['Close'])
data
# Out:
#                 Close
# Date
# 2012-01-03   8.410000
# 2012-01-04   8.600000
# 2012-01-05   8.620000
# 2012-01-06   8.520000
# 2012-01-09   8.590000
# ...               ...
# 2021-08-31  49.779999
# 2021-09-01  49.549999
# 2021-09-02  49.599998
# 2021-09-03  48.860001
# 2021-09-07  48.419998
#
# [2436 rows x 1 columns]

# %%
# Convert the dataframe to a numpy array
dataset = data.values

# %%
dataset.shape
# Out:
# (2436, 1)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

# %%
training_data_len = int(np.ceil( len(dataset) * .9 ))
train_data = scaled_data[0:int(training_data_len), :]

# %%
train_data.shape
# Out:
# (2193, 1)

# %%
def train_val(data):
    train_size = int(len(data) * 0.8)
    train = data[0:train_size]
    val= data[train_size:len(data)]
    return train, val

# %%
train_1, val_1 = train_val(train_data)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(train_1, label='train')
ax.plot(val_1, label='test')
ax.set_title('Train-Test Split');
plt.legend();

# %%
#The LSTM needs data with the format of [samples, time steps and features]
#[10 20 30] 40
#[20 30 40] 50
#[30 40 50] 60
#using the size of time step as a batch to predict the next value 

def split_sequence(sequence, n_steps):
#convert input data into 3-D array as required for LSTM network
    
    X, y = [], []
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
def prepare_training(data, n_steps):
    #data = to_dataset(data)
    train, val = train_val(data)
    x_train, y_train = split_sequence(train, n_steps)
    x_val, y_val = split_sequence(val, n_steps)
    features = 1
    return x_train, y_train, x_val, y_val, features

# %%
# Model
def creat_model1(n_steps, features):
    model = Sequential()
    model.add(LSTM(128, activation='relu', return_sequences=False, input_shape=(n_steps, features)))
    model.add(RepeatVector(n_steps))
    model.add(LSTM(128, activation='relu', return_sequences=False))
    model.add(Dense(features))
    
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    return model

# %%
def creat_model2(n_steps, features):
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
    model.add(LSTM(64, return_sequences=False))
    model.add(Dense(25))
    model.add(Dropout(0.3))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    return model

# %%
#Bidirectional allows the model learn the input sequence both forward and backwards

def creat_model3(n_steps, features):
    model = Sequential()
    model.add(LSTM(200, input_shape=(n_steps, features)))
    model.add(RepeatVector(n_steps))
    model.add(Bidirectional(LSTM(200, activation='relu', return_sequences=False)))
    model.add(Dense(features))

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    return model

# %%
def creat_model4(n_steps, features):
    model = Sequential()
    model.add(LSTM(128, activation='relu', input_shape=(n_steps, features), return_sequences=True))
    model.add(LSTM(64, activation='relu', return_sequences=False))
    model.add(RepeatVector(n_steps))
    model.add(LSTM(64, activation='relu', return_sequences=True))
    model.add(LSTM(128, activation='relu', return_sequences=False))
    model.add(Dense(features))

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    return model

# %%
n_steps = 10

x_train, y_train, x_val, y_val, feature = prepare_training(train_data,n_steps)

# %%
x_train.shape
# Out:
# (1744, 10, 1)

# %%
y_train.shape
# Out:
# (1744, 1)

# %%
#Stop training when a monitored metric has stopped improving.
early = EarlyStopping(monitor='val_loss',patience=5)

#Reduce learning rate when a metric has stopped improving.
reduce = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.2, mil_lr=0.001)

# %% [markdown]
# ## Test data set

# %%
test_data = scaled_data[training_data_len: , :]
x_test, y_test = split_sequence(test_data, n_steps)

# %%
y_test_re = scaler.inverse_transform(y_test)

# %%
y_test_re.shape
# Out:
# (233, 1)

# %% [markdown]
# ## Model 1

# %%
model1 = creat_model1(n_steps, feature)

# %%
history1 = model1.fit(x_train, y_train, epochs=50, batch_size=50, verbose=1,
         validation_data=(x_val, y_val), callbacks=[early,reduce])
# Out:
# Epoch 1/50
# 35/35 [==============================] - 2s 37ms/step - loss: 0.1397 - mean_squared_error: 0.1397 - val_loss: 9.9230e-04 - val_mean_squared_error: 9.9230e-04
# Epoch 2/50
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 3/50
# 35/35 [==============================] - 1s 19ms/step - loss: 4.1969e-04 - mean_squared_error: 4.1969e-04 - val_loss: 9.9084e-04 - val_mean_squared_error: 9.9084e-04
# Epoch 4/50
# 35/35 [==============================] - 1s 19ms/step - loss: 3.7378e-04 - mean_squared_error: 3.7378e-04 - val_loss: 9.4659e-04 - val_mean_squared_error: 9.4659e-04
# Epoch 5/50
# 35/35 [==============================] - 1s 20ms/step - loss: 3.5414e-04 - mean_squared_error: 3.5414e-04 - val_loss: 9.4454e-04 - val_mean_squared_error: 9.4454e-04
# Epoch 6/50
# 35/35 [==============================] - 1s 19ms/step - loss: 3.1964e-04 - mean_squared_error: 3.1964e-04 - val_loss: 9.3962e-04 - val_mean_squared_error: 9.3962e-04
# Epoch 7/50
# 35/35 [==============================] - 1s 20ms/step - loss: 3.4504e-04 - mean_squared_error: 3.4504e-04 - val_loss: 9.3409e-04 - val_mean_squared_error: 9.3409e-04
# Epoch 8/50
# 35/35 [==============================] - 1s 19ms/step - loss: 3.2379e-04 - mean_squared_error: 3.2379e-04 - val_loss: 9.3468e-04 - val_mean_squared_error: 9.3468e-04
# Epoch 9/50
# 35/35 [==============================] - 1s 19ms/step - loss: 3.0948e-04 - mean_squared_error: 3.0948e-04 - val_loss: 9.3148e-04 - val_mean_squared_error: 9.3148e-04
# 35/35 [==============================] - 1s 19ms/step - loss: 3.1783e-04 - mean_squared_error: 3.1783e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04
# Epoch 26/50
# 35/35 [==============================] - 1s 19ms/step - loss: 3.2665e-04 - mean_squared_error: 3.2665e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04
# Epoch 27/50
# 35/35 [==============================] - 1s 19ms/step - loss: 3.4525e-04 - mean_squared_error: 3.4525e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04
# Epoch 28/50
# 35/35 [==============================] - 1s 21ms/step - loss: 3.2539e-04 - mean_squared_error: 3.2539e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04
# Epoch 29/50
# 35/35 [==============================] - 1s 21ms/step - loss: 3.4185e-04 - mean_squared_error: 3.4185e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04
# Epoch 30/50
# 35/35 [==============================] - 1s 19ms/step - loss: 3.6707e-04 - mean_squared_error: 3.6707e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04
# Epoch 31/50
# 35/35 [==============================] - 1s 21ms/step - loss: 3.4236e-04 - mean_squared_error: 3.4236e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04
# Epoch 32/50
# 35/35 [==============================] - 1s 20ms/step - loss: 3.4581e-04 - mean_squared_error: 3.4581e-04 - val_loss: 9.2979e-04 - val_mean_squared_error: 9.2979e-04

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               66560
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 10, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 198,273
# Trainable params: 198,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Get the models predicted price values 
predictions1 = model1.predict(x_test)

# %%
predictions1.shape
# Out:
# (233, 1)

# %%
predictions1 = scaler.inverse_transform(predictions1)

# %%
# Get the root mean squared error (RMSE)
##import math
#math.sqrt(mean_squared_error(y_test_re,predictions))
rmse1 = np.sqrt(np.mean(((predictions1 -y_test_re) ** 2)))
print(f'RMSE：{np.round(rmse1, 4)}')
# Out:
# RMSE：1.5215

# %% [markdown]
# ## Model 2

# %%
model2 = creat_model2(n_steps, feature)

# %%
history2 = model2.fit(x_train, y_train, epochs=50, batch_size=50, verbose=1,
         validation_data=(x_val, y_val), callbacks=[early,reduce])
# Out:
# Epoch 1/50
# 35/35 [==============================] - 2s 26ms/step - loss: 0.0960 - mean_squared_error: 0.0960 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 2/50
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 3/50
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 4/50
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 5/50
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 6/50
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 7/50
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 8/50
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 9/50
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0018 - val_mean_squared_error: 0.0018

# %%
predictions2 = model2.predict(x_test)

# %%
predictions2 = scaler.inverse_transform(predictions2)

# %%
rmse2 = np.sqrt(np.mean(((predictions2 -y_test_re) ** 2)))
print(f'RMSE：{np.round(rmse2, 4)}')
# Out:
# RMSE：2.3702

# %% [markdown]
# ## Model 3

# %%
model3 = creat_model3(n_steps, feature)

# %%
history3 = model3.fit(x_train, y_train, epochs=50, batch_size=50, verbose=1,
         validation_data=(x_val, y_val), callbacks=[early,reduce])
# Out:
# Epoch 1/50
# 35/35 [==============================] - 4s 56ms/step - loss: 0.0814 - mean_squared_error: 0.0814 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch
# Epoch 18/50
# 35/35 [==============================] - 2s 44ms/step - loss: 3.3342e-04 - mean_squared_error: 3.3342e-04 - val_loss: 9.3169e-04 - val_mean_squared_error: 9.3169e-04

# %%
predictions3 = model3.predict(x_test)

# %%
predictions3.shape
# Out:
# (233, 1)

# %%
predictions3 = scaler.inverse_transform(predictions3)

# %%
rmse3 = np.sqrt(np.mean(((predictions3 -y_test_re) ** 2)))
print(f'RMSE：{np.round(rmse3, 4)}')
# Out:
# RMSE：1.5036

# %% [markdown]
# ## Model 4

# %%
model4 = creat_model4(n_steps, feature)

# %%
history4 = model4.fit(x_train, y_train, epochs=50, batch_size=50, verbose=1,
         validation_data=(x_val, y_val), callbacks=[early,reduce])
# Out:
# Epoch 1/50
# 35/35 [==============================] - 3s 37ms/step - loss: 0.1817 - mean_squared_error: 0.1817 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 2/50
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 3/50
# 35/35 [==============================] - 1s 27ms/step - loss: 7.9230e-04 - mean_squared_error: 7.9230e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 4/50
# 35/35 [==============================] - 1s 27ms/step - loss: 6.6832e-04 - mean_squared_error: 6.6832e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 5/50
# 35/35 [==============================] - 1s 27ms/step - loss: 7.2415e-04 - mean_squared_error: 7.2415e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 6/50
# 35/35 [==============================] - 1s 28ms/step - loss: 6.0400e-04 - mean_squared_error: 6.0400e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 7/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.9345e-04 - mean_squared_error: 5.9345e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 8/50
# 35/35 [==============================] - 1s 27ms/step - loss: 6.3667e-04 - mean_squared_error: 6.3667e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 9/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.9116e-04 - mean_squared_error: 5.9116e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 10/50
# 35/35 [==============================] - 1s 30ms/step - loss: 5.5935e-04 - mean_squared_error: 5.5935e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 11/50
# 35/35 [==============================] - 1s 29ms/step - loss: 6.0235e-04 - mean_squared_error: 6.0235e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 12/50
# 35/35 [==============================] - 1s 29ms/step - loss: 5.6728e-04 - mean_squared_error: 5.6728e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 13/50
# 35/35 [==============================] - 1s 29ms/step - loss: 6.2610e-04 - mean_squared_error: 6.2610e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 14/50
# 35/35 [==============================] - 1s 28ms/step - loss: 5.7193e-04 - mean_squared_error: 5.7193e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 15/50
# 35/35 [==============================] - 1s 29ms/step - loss: 6.1683e-04 - mean_squared_error: 6.1683e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 16/50
# 35/35 [==============================] - 1s 27ms/step - loss: 6.2819e-04 - mean_squared_error: 6.2819e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 17/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.3306e-04 - mean_squared_error: 5.3306e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 18/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.7329e-04 - mean_squared_error: 5.7329e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 19/50
# 35/35 [==============================] - 1s 27ms/step - loss: 6.0168e-04 - mean_squared_error: 6.0168e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 20/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.4470e-04 - mean_squared_error: 5.4470e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 21/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.8102e-04 - mean_squared_error: 5.8102e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 22/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.7423e-04 - mean_squared_error: 5.7423e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 23/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.5674e-04 - mean_squared_error: 5.5674e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 24/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.8758e-04 - mean_squared_error: 5.8758e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 25/50
# 35/35 [==============================] - 1s 32ms/step - loss: 5.9784e-04 - mean_squared_error: 5.9784e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 26/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.9260e-04 - mean_squared_error: 5.9260e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 27/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.7898e-04 - mean_squared_error: 5.7898e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 28/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.8370e-04 - mean_squared_error: 5.8370e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 29/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.2567e-04 - mean_squared_error: 5.2567e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 30/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.7357e-04 - mean_squared_error: 5.7357e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 31/50
# 35/35 [==============================] - 1s 27ms/step - loss: 6.1997e-04 - mean_squared_error: 6.1997e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 32/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.7548e-04 - mean_squared_error: 5.7548e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 33/50
# 35/35 [==============================] - 1s 27ms/step - loss: 5.4501e-04 - mean_squared_error: 5.4501e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016

# %%
predictions4 = model4.predict(x_test)

# %%
predictions4 = scaler.inverse_transform(predictions4)

# %%
rmse4 = np.sqrt(np.mean(((predictions4 -y_test_re) ** 2)))
print(f'RMSE：{np.round(rmse4, 4)}')
# Out:
# RMSE：1.8865

# %% [markdown]
# ## Plots

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend(['Train','Val']);

# %%
plt.plot(history3.history['mean_squared_error'])
plt.plot(history3.history['val_mean_squared_error'])
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend(['Train','Val']);

# %%
plt.figure(figsize=(16,6))
plt.plot(y_test_re)
plt.plot(predictions3)
plt.legend(['Real Value','Predicted Value']);

# %%
train = data[:training_data_len]
test = data[training_data_len+10:]

# %%
test.shape
# Out:
# (233, 1)

# %%
predictions3.shape
# Out:
# (233, 1)

# %%
test['Predictions'] = predictions3

# %%
# Visualize the data

with plt.style.context('images/presentation.mplstyle'):
    plt.figure(figsize=(16,6))
    plt.title('Model')
    plt.xlabel('Date', fontsize=18)
    plt.ylabel('Close Price USD ($)', fontsize=18)
    plt.plot(train['Close'], 'c')
    plt.plot(test['Close'], 'r')
    plt.plot(test['Predictions'], 'g')
    plt.legend(['Train', 'Test', 'Predictions'], loc='lower right')
    plt.show()
    
    plt.savefig('images/LSTM.png')

# %%
test
# Out:
#                 Close  Predictions
# Date
# 2020-10-02  38.759998    37.784786
# 2020-10-05  38.490002    38.023224
# 2020-10-06  37.580002    38.176765
# 2020-10-07  38.590000    38.070576
# 2020-10-08  38.990002    38.228676
# ...               ...          ...
# 2021-08-30  49.169998    50.072674
# 2021-08-31  49.779999    49.896149
# 2021-09-01  49.549999    49.902809
# 2021-09-02  49.599998    49.846931
# 2021-09-03  48.860001    49.816528
#
# [233 rows x 2 columns]
